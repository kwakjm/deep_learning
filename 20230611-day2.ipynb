# %%
# 텐서플로우를 활용한 선형 회귀분석
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([2,4,6,8])
y = np.array([81,93,91,97])

model = Sequential()   # 모델 생성
model.add(Dense(1, input_dim=1, activation='linear'))  # layer 추가
model.compile(optimizer='sgd', loss='mse')  # 학습 컴파일 옵션

# 모델 학습
model.fit(x, y, epochs=2000)  # 반복은 2000회

# 그래프로 확인
plt.scatter(x,y)  # 원 데이터를 scatter 로 그림
plt.plot(x, model.predict(x), 'r')  # 예측값을 선으로 표기
plt.show()
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 314ms/step - loss: 7694.6982
# Epoch 2/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 1964.5085
# Epoch 3/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 1117.5300
# Epoch 4/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 987.8080
# Epoch 5/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 963.4677
# Epoch 6/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 954.6395
# Epoch 7/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 948.1237
# Epoch 8/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 941.9813
# Epoch 9/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 935.9273
# Epoch 10/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 929.9197
# Epoch 11/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 923.9520
# Epoch 12/2000
# ...

# %%
# 7시간을 공부했을때 성적을 예측
hour = [7, 5, 11]
model.predict(hour)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# array([[ 95.11999],
#        [ 90.48126],
#        [104.39744]], dtype=float32)

# %%
# 다중 선형 회귀 분석 -> 텐서플로우로 
# x1 = np.array([2,4,6,8])
# x2 = np.array([0,4,2,3])
x = np.array([[2,0],[4,4],[6, 2],[8, 3]])
y = np.array([81,93,91,97])

model = Sequential()   # 모델 생성
model.add(Dense(10, input_dim=2, activation='relu'))  # layer 추가
model.add(Dense(1, activation='linear'))  # layer 추가
model.compile(optimizer='sgd', loss='mse')  # 학습 컴파일 옵션

# 모델 학습
model.fit(x, y, epochs=2000)  # 반복은 2000회
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 316ms/step - loss: 8150.5039
# Epoch 2/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 91075.1094
# Epoch 3/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 8867.9219
# Epoch 4/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 8518.1289
# Epoch 5/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 8182.1855
# Epoch 6/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 7859.5474
# Epoch 7/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 7549.6855
# Epoch 8/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 7252.0947
# Epoch 9/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 6966.2871
# Epoch 10/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 6691.7983
# Epoch 11/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 6428.1792
# Epoch 12/2000
# ...

# %%
# 7시간, 과외를 4회 했을때 성적을 예측
hour = 7
cnt = 4
model.predict([[hour, cnt]])
# Out:
# 1/1 [==============================] - 0s 73ms/step
# array([[90.49982]], dtype=float32)

# %%
# 로지스틱 회귀분석 
x = np.array([2,4,6,8,10,12,14])
y = np.array([0,0,0,1,1,1,1])

model = Sequential()
model.add(Dense(1, input_dim=1, activation='sigmoid'))  # 이진 분류이므로 시그모이드 함수 사용
model.compile(optimizer='sgd', loss='binary_crossentropy')
model.fit(x,y,epochs=5000)

# 그래프로 확인
plt.scatter(x,y)  # 원 데이터를 scatter 로 그림
plt.plot(x, model.predict(x), 'r')  # 예측값을 선으로 표기
plt.show()

# 공부시간이 7시간인 경우 합격 여부 확인
model.predict([7])
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 347ms/step - loss: 7.3307
# Epoch 2/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.9367
# Epoch 3/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 6.5433
# Epoch 4/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.1508
# Epoch 5/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 5.7592
# Epoch 6/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.3689
# Epoch 7/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.9802
# Epoch 8/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5933
# Epoch 9/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2088
# Epoch 10/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.8274
# Epoch 11/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.4501
# Epoch 12/5000
# ...

# %%
# 다층 퍼셉트론으로 XOR 문제 해결
w11 = np.array([-2, -2])
w12 = np.array([2, 2])
w2 = np.array([ 1, 1])
b1 = 3
b2 = -1
b3 = -1

# 퍼셉트론 함수 
def MLP(x, w, b):
    y = np.sum(x * w) + b
    if y <= 0:
        return 0
    else:
        return 1

# NAND 게이트 
def NAND(x1, x2):
    return MLP(np.array([x1, x2]), w11, b1)

# OR 게이트
def OR(x1, x2):
    return MLP(np.array([x1,x2]), w12, b2)

def AND(x1, x2):
    return MLP(np.array([x1,x2]), w2, b3)

def XOR(x1,x2):
    return AND(NAND(x1, x2), OR(x1,x2))

# %%
for x in [[0,0], [0,1], [1,0], [1,1]]:
    y = XOR(x[0], x[1])
    print("입력 값 :", str(x), " 출력 값 : ",str(y))
# Out:
# 입력 값 : [0, 0]  출력 값 :  0
# 입력 값 : [0, 1]  출력 값 :  1
# 입력 값 : [1, 0]  출력 값 :  1
# 입력 값 : [1, 1]  출력 값 :  0

# %%
# 폐암 수술 후 1년이내에 사망자와 생존자의 자료를 가지고 학습
# np.loadtxt("./data/ThoraricSurgery3.csv", delimiter='')
# 1. HIDDEN LAYER는 2개층 -> 처음 node수가 30개, 두번째 10개
# 2. 적절한 활성함수 사용
# 3. 손실함수와 옵티마이저를 sgd, adam을 사용해서 결과 비교 
 
data = np.loadtxt('./data/ThoraricSurgery3.csv', delimiter=',')
x = data[:, 0:-1]  # x 요소  , 마지막 자료는 target
y = data[:, -1]   # target

# %%
# 1. hidden layer 는 2개층 -> 처음 node수가 30개, 두번째 10개
# 2. 적절한 활성함수 사용'
def make_model(input_dim):
    model = Sequential()
    model.add(Dense(30, input_dim=input_dim, activation='relu'))  # 처음은 input_dim 필요
    # 두번째 layer부터는 input_dim 필요 없음, 이전 layer의 out node의 개수가 input_dim 수 
    model.add(Dense(10, activation='relu'))   
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# 3. 손실함수와 옵티마이저를 sgd, adam을 사용해서 결과 비교 
model1 = make_model(x.shape[1])
model1.compile(loss='binary_crossentropy', optimizer='sgd',metrics=['accuracy'])

# 모델 학습
model1.fit(x,y,epochs=2000, verbose=False)

# %%
print(model1.history.history['loss'][-1])  # 마지감 손실함수의 값 출력
# 데이터 예측
predict_result = model1.predict(x[-1].reshape(1,-1))
print(f"실제 값 :{y[-1]},  예측 값 : {predict_result }")
# Out:
# 0.39550065994262695
# 1/1 [==============================] - 0s 63ms/step
# 실제 값 :0.0,  예측 값 : [[0.08651246]]

# %%
model2 = make_model(x.shape[1])
model2.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# 모델 학습
model2.fit(x,y,epochs=2000, verbose=False)
print(model2.history.history['loss'][-1])  # 마지감 손실함수의 값 출력
# 데이터 예측
predict_result = model2.predict(x[-1].reshape(1,-1))
print(f"실제 값 :{y[-1]},  예측 값 : {predict_result }")
# Out:
# 0.2502255141735077
# 1/1 [==============================] - 0s 61ms/step
# 실제 값 :0.0,  예측 값 : [[0.01603774]]
